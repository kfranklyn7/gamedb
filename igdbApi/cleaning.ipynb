# %%
import pandas as pd
import numpy as np
import csv

# %%
artworks_db = pd.read_json('artworks.json')
artworks_db.set_index('id', drop=True,inplace=True)
artworks_db.head()
# Out:
#      game  height              image_id  \
# id
# 2   23248  1080.0  nfoayruxc3ze4yccf5ey
# 3   23248  1080.0  bzmmhgsskzw2plzpmabo
# 4   23248  1080.0  qira2bnppcegot3dzlgk
# 7   31712  1160.0  p9yyozft35nx7aoi8khj
# 8   16999  3530.0  kxwrcnqgh1nffr9vg4ly
#
#                                                   url   width  \
# id
# 2   //images.igdb.com/igdb/image/upload/t_thumb/nf...  1920.0
# 3   //images.igdb.com/igdb/image/upload/t_thumb/bz...  1920.0
# 4   //images.igdb.com/igdb/image/upload/t_thumb/qi...  1920.0
# 7   //images.igdb.com/igdb/image/upload/t_thumb/p9...  1920.0
# 8   //images.igdb.com/igdb/image/upload/t_thumb/kx...  6160.0
#
#                                 checksum  artwork_type  alpha_channel  \
# id
# 2   a9cc2277-18f4-5ce6-0cf3-54f7a9c46c77           1.0            NaN
# 3   358ce8a7-0f23-f03b-e9f1-61d2481ee1ac           1.0            NaN
# 4   48e6cf03-f489-859a-f63d-45bd5962c253           1.0            NaN
# ...

# %%
companies_db = pd.read_json('companies.json')
companies_db.set_index('id', drop=True,inplace=True)
companies_db.head()
# Out:
#      change_date_category  country          created_at  \
# id
# 444                     7    124.0 2011-10-04 10:38:08
# 221                     7    826.0 2011-04-08 12:59:45
# 19                      7    250.0 2011-03-04 18:57:50
# 302                     0      NaN 2011-04-13 09:20:57
# 165                     0      NaN 2011-03-30 19:43:08
#
#                                            description  \
# id
# 444  Radical Entertainment Inc. is a Canadian video...
# 221  Splash Damage Ltd. is an independent British v...
# 19   Founded in 1999, Arkane Studios has grown to b...
# 302                                                NaN
# 165                                                NaN
#
#                                              developed    logo  \
# id
# 444  [3869, 3949, 3954, 2844, 5139, 5868, 210116, 8...   387.0
# 221  [502, 2987, 680, 28991, 28990, 103291, 1902, 2...   304.0
# 19   [533, 11118, 51690, 19531, 52899, 103306, 1033...  7885.0
# ...

# %%
# with open('covers.json', 'r') as f:
#     content = f.read().strip()
#     print(f"File content length: {len(content)}")
#     print(f"First 50 characters: {content[:500]}")
covers_db = pd.read_json('covers.json')
covers_db.set_index('id', drop=True,inplace=True)
covers_db.head()
# Out:
#       game  height              image_id  \
# id
# 109  108.0   500.0  pmjszoa4lgd7nznewajq
# 243  252.0   670.0  vqf2wnwpoktu231nfc2p
# 249  258.0   650.0  eojokuktlkawq6nr1v9i
# 250  259.0   351.0  eye80lpmtwdjqjzww7jz
# 252  261.0   300.0  gzwehl7lyeabjbglisl4
#
#                                                    url  width  \
# id
# 109  //images.igdb.com/igdb/image/upload/t_thumb/pm...  384.0
# 243  //images.igdb.com/igdb/image/upload/t_thumb/vq...  553.0
# 249  //images.igdb.com/igdb/image/upload/t_thumb/eo...  665.0
# 250  //images.igdb.com/igdb/image/upload/t_thumb/ey...  350.0
# 252  //images.igdb.com/igdb/image/upload/t_thumb/gz...  214.0
#
#                                  checksum  alpha_channel  animated  \
# id
# 109  e057cbf1-a627-8cb4-6fc5-021a5e06403d            NaN       NaN
# 243  6d0c6b77-19c3-0f5f-563a-bb1bae8a6203            NaN       NaN
# 249  f29574c5-ede1-4c68-1e40-e2b5887191fc            NaN       NaN
# ...

# %%
games_db = pd.read_json('games.json')
games_db.set_index('id', drop=True,inplace=True)
games_db.drop('created_at', axis=1, inplace=True)
games_db.drop('updated_at', axis=1, inplace=True)
games_db.head()
# Out:
#                       age_ratings  aggregated_rating  aggregated_rating_count  \
# id
# 145                [15740, 32527]              75.00                      3.0
# 414           [45966, 371, 69596]              90.00                      1.0
# 484  [63718, 33972, 63719, 33973]              80.25                      4.0
# 462               [86688, 123695]              20.00                      1.0
# 322                [5599, 124411]                NaN                      NaN
#
#                             alternative_names          bundles     cover  \
# id
# 145                     [17153, 27771, 42498]  [150523, 77212]  128838.0
# 414                                   [82107]              NaN   89377.0
# 484       [35085, 35088, 55074, 57346, 57347]              NaN  134738.0
# 462                            [18656, 40756]              NaN  274020.0
# 322  [152614, 152615, 152971, 177479, 180664]              NaN   93277.0
#
# ...

# %%
genres_db = pd.read_json('genres.json')
genres_db.set_index('id', drop=True,inplace=True)
genres_db.head()
genres_db.drop('created_at', axis=1, inplace=True)
genres_db.drop('updated_at', axis=1, inplace=True)
genres_db.head()
# Out:
#                name             slug  \
# id
# 2   Point-and-click  point-and-click
# 4          Fighting         fighting
# 5           Shooter          shooter
# 7             Music            music
# 8          Platform         platform
#
#                                             url  \
# id
# 2   https://www.igdb.com/genres/point-and-click
# 4          https://www.igdb.com/genres/fighting
# 5           https://www.igdb.com/genres/shooter
# 7             https://www.igdb.com/genres/music
# 8          https://www.igdb.com/genres/platform
#
#                                 checksum
# id
# 2   b295f28a-5f68-fc3e-5de2-f3195e10d160
# 4   d23da988-5bb7-011e-34dc-0b712765e470
# 5   20c255bc-ec2d-c219-34bd-47995b0a79f1
# 7   cbf12469-a5a8-6974-086c-ec9c6aeb5791
# 8   06c188b9-1058-933f-dfee-4ec658117ad2

# %%
involved_companies_db = pd.read_json('involved_companies.json')
involved_companies_db.set_index('id', drop=True,inplace=True)
involved_companies_db.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 involved_companies_db = pd.read_json('involved_companies.json')
#       2 involved_companies_db.set_index('id', drop=True,inplace=True)
#       3 involved_companies_db.head()
#
# File ~\miniconda3\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\miniconda3\Lib\site-packages\pandas\io\json\_json.py:1014, in JsonReader.read(self)
#    1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# -> 1014     obj = self._get_object_parser(self.data)
# ...

# %%
platforms_db = pd.read_json('platforms.json')
platforms_db.set_index('id', drop=True,inplace=True)
platforms_db.drop('created_at', axis=1, inplace=True)
platforms_db.drop('updated_at', axis=1, inplace=True)
platforms_db.head()
# Out:
#                                     alternative_name  generation  \
# id
# 376                       YENO Super Cassette Vision         3.0
# 12                                              X360         7.0
# 32   JVC Saturn, Hi-Saturn, Samsung Saturn, V-Saturn         5.0
# 62                                               NaN         5.0
# 148                                              NaN         NaN
#
#                             name  platform_logo                         slug  \
# id
# 376  Epoch Super Cassette Vision          743.0  epoch-super-cassette-vision
# 12                      Xbox 360          622.0                      xbox360
# 32                   Sega Saturn           49.0                       saturn
# 62                  Atari Jaguar          286.0                       jaguar
# 148                    AY-3-8607            NaN                    ay-3-8607
#
#                                                    url         versions  \
# id
# ...

# %%
franchises_db = pd.read_json('franchises.json')
franchises_db.set_index('id', drop=True,inplace=True)
franchises_db.drop('created_at', axis=1, inplace=True)
franchises_db.drop('updated_at', axis=1, inplace=True)
franchises_db.head()
# Out:
#                                                  games          name  \
# id
# 295                                             [4815]       The Dog
# 144  [2785, 2809, 2810, 3248, 21151, 241137, 259229...  Johnny Bravo
# 21                                            [140690]    BloodRayne
# 215  [4003, 5005, 12898, 119167, 43745, 69996, 1990...  Men in Black
# 163       [3763, 300925, 354104, 95099, 63420, 324566]   Pacific Rim
#
#              slug                                           url  \
# id
# 295       the-dog       https://www.igdb.com/franchises/the-dog
# 144  johnny-bravo  https://www.igdb.com/franchises/johnny-bravo
# 21     bloodrayne    https://www.igdb.com/franchises/bloodrayne
# 215  men-in-black  https://www.igdb.com/franchises/men-in-black
# 163   pacific-rim   https://www.igdb.com/franchises/pacific-rim
#
#                                  checksum
# id
# 295  01cc866b-0d90-4a83-4335-78a47ac495f2
# 144  b0e12f7d-9893-b13e-cb1d-9f296f1e3610
# ...

# %%
game_modes_db = pd.read_json('game_modes.json')
game_modes_db.set_index('id', drop=True,inplace=True)
game_modes_db.drop('created_at', axis=1, inplace=True)
game_modes_db.drop('updated_at', axis=1, inplace=True)
game_modes_db.head()
# Out:
#                                   name                              slug  \
# id
# 1                        Single player                     single-player
# 2                          Multiplayer                       multiplayer
# 3                         Co-operative                      co-operative
# 4                         Split screen                      split-screen
# 5   Massively Multiplayer Online (MMO)  massively-multiplayer-online-mmo
#
#                                                   url  \
# id
# 1       https://www.igdb.com/game_modes/single-player
# 2         https://www.igdb.com/game_modes/multiplayer
# 3        https://www.igdb.com/game_modes/co-operative
# 4        https://www.igdb.com/game_modes/split-screen
# 5   https://www.igdb.com/game_modes/massively-mult...
#
#                                 checksum
# id
# 1   1cc07088-c5fb-3cb2-9e68-af6620c18836
# 2   3ffef62b-e19f-6bab-d510-98385c06d902
# 3   d154173b-5bdf-5fda-5969-e4c87e135d1a
# ...

# %%
release_dates_db = pd.read_json('release_dates.json')
release_dates_db.set_index('id', drop=True,inplace=True)
release_dates_db.drop('created_at', axis=1, inplace=True)
release_dates_db.drop('updated_at', axis=1, inplace=True)
release_dates_db.head()
# Out:
#              date  game         human     m  platform       y  \
# id
# 139  1.319501e+09   343  Oct 25, 2011  10.0         6  2011.0
# 128  1.248912e+09   215  Jul 30, 2009   7.0        14  2009.0
# 333  1.204589e+09   468  Mar 04, 2008   3.0         6  2008.0
# 119  1.255392e+09   212  Oct 13, 2009  10.0        12  2009.0
# 48   1.101168e+09   123  Nov 23, 2004  11.0        14  2004.0
#
#                                  checksum  date_format  release_region  status
# id
# 139  5a56b1f6-3226-4912-307b-d5ef6edc825c            0               8     NaN
# 128  95dd9bd0-4cd6-c4ff-a828-881bdbd9f614            0               8     NaN
# 333  21e6ec6e-76df-1a00-5262-3cbf47f8a959            0               8     NaN
# 119  7e3f38b9-e9e5-8814-f938-8361f756f625            0               8     NaN
# 48   597c4e9b-f7b1-d7df-be5b-51855c2460b6            0               8     NaN

# %%
screenshots_db = pd.read_json('screenshots.json')
screenshots_db.set_index('id', drop=True,inplace=True)
screenshots_db.head()
# Out:
#         alpha_channel  animated    game  height image_id  \
# id
# 499000            0.0       0.0  153519  1080.0   scap14
# 499001            0.0       0.0  153519  1080.0   scap15
# 499002            0.0       0.0   73152   480.0   scap16
# 499003            0.0       0.0   73152   480.0   scap17
# 499004            0.0       0.0   73152   323.0   scap18
#
#                                                       url   width  \
# id
# 499000  //images.igdb.com/igdb/image/upload/t_thumb/sc...  1920.0
# 499001  //images.igdb.com/igdb/image/upload/t_thumb/sc...  1920.0
# 499002  //images.igdb.com/igdb/image/upload/t_thumb/sc...   704.0
# 499003  //images.igdb.com/igdb/image/upload/t_thumb/sc...   704.0
# 499004  //images.igdb.com/igdb/image/upload/t_thumb/sc...   474.0
#
#                                     checksum
# id
# 499000  af8ae9ff-f473-613d-a957-ae9161265e5a
# 499001  86aa5366-45c5-a18d-42d4-a324c343a177
# 499002  ddfff066-1a58-620c-c9fe-daa9d3174fde
# ...

# %%
themes_db = pd.read_json('themes.json')
themes_db.set_index('id', drop=True,inplace=True)
themes_db.drop('created_at', axis=1, inplace=True)
themes_db.drop('updated_at', axis=1, inplace=True)
themes_db.head()
# Out:
#            name         slug                                      url  \
# id
# 31        Drama        drama        https://www.igdb.com/themes/drama
# 32  Non-fiction  non-fiction  https://www.igdb.com/themes/non-fiction
# 33      Sandbox      sandbox      https://www.igdb.com/themes/sandbox
# 34  Educational  educational  https://www.igdb.com/themes/educational
# 35         Kids         kids         https://www.igdb.com/themes/kids
#
#                                 checksum
# id
# 31  a10308c4-a660-7016-742b-ec956e9e9675
# 32  64d7a553-bbf8-1bbb-fc3c-8b1f7e404f5e
# 33  e2f2c5b2-16ea-6e44-e2bb-af500d0b3f97
# 34  91f581b0-62df-6d68-b7fc-1d4f1bc6d4fa
# 35  95416d52-fb76-9995-f035-ee86bafbe5c4

# %%
keywords_db = pd.read_json('keywords.json')
keywords_db.set_index('id', drop=True,inplace=True)
keywords_db.drop('created_at', axis=1, inplace=True)
keywords_db.drop('updated_at', axis=1, inplace=True)
keywords_db.head()
# Out:
#                   name               slug  \
# id
# 497  summoning support  summoning-support
# 44          ice hockey         ice-hockey
# 51      space strategy     space-strategy
# 313              rugby              rugby
# 66   simulated reality  simulated-reality
#
#                                                    url  \
# id
# 497  https://www.igdb.com/categories/summoning-support
# 44          https://www.igdb.com/categories/ice-hockey
# 51      https://www.igdb.com/categories/space-strategy
# 313              https://www.igdb.com/categories/rugby
# 66   https://www.igdb.com/categories/simulated-reality
#
#                                  checksum
# id
# 497  12253aae-f527-2afb-f9fd-e2f760513c24
# 44   51dfbc03-e82a-db6c-af06-d642a5ca7bd1
# 51   a253f912-5e2e-8f80-70e3-b1548333b340
# 313  1c310b60-20bd-62b9-5680-104a19b0e823
# 66   197b1124-3dd2-500f-94d9-bd15e30f9a34

# %%
collections_db = pd.read_json('collections.json')
collections_db.head()
collections_db.set_index('id', drop=True,inplace=True)
collections_db.drop('created_at', axis=1, inplace=True)
collections_db.drop('updated_at', axis=1, inplace=True)
# collections_db.head(10)
# Out:
#                                                  games  \
# id
# 110                                              [557]
# 376                        [2028, 10274, 10275, 16121]
# 229                  [1023, 1024, 10393, 10394, 65862]
# 69   [18928, 56624, 57033, 57034, 77971, 78448, 784...
# 274  [1233, 1232, 1230, 45253, 1231, 129891, 70514,...
# ..                                                 ...
# 456                                 [2249, 2250, 2251]
# 184  [794, 810, 924, 934, 935, 940, 2588, 4323, 882...
# 224                                 [612, 919, 116634]
# 332  [1677, 1678, 1679, 1680, 1681, 1682, 1683, 263...
# 149         [840, 962, 963, 285, 71480, 10743, 350134]
#
#                               name                           slug  \
# id
# 110                   Prison Break                   prison-break
# 376                   Elven Legacy                   elven-legacy
# 229               Hacker Evolution               hacker-evolution
# ...

# %%
# artworks_db.to_csv('artworks.csv')
# companies_db.to_csv('companies.csv')
# covers_db.to_csv('covers.csv')
# franchises_db.to_csv('franchises.csv')
# games_db.to_csv('games.csv')
# game_modes_db.to_csv('game_modes.csv')
# release_dates_db.to_csv('release_dates.csv')
# keywords_db.to_csv('keywords.csv')
# screenshots_db.to_csv('screenshots.csv')
# themes_db.to_csv('themes.csv')
# genres_db.to_csv('genres.csv')
# involved_companies_db.to_csv('involved_companies.csv')
# platforms_db.to_csv('platforms.csv')
collections_db.to_csv('collections.csv')
